# %%
#importing all libraries that are required
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import sklearn as sk
import math
from sklearn.preprocessing import StandardScaler
import random
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
import warnings
warnings.simplefilter("ignore")

# %%
#reading csv data as dataframe
df = pd.read_csv('AER_credit_card_data.csv')

# %%
# droping features that are not requied
df.drop([ 'share', 'expenditure', 'dependents', 'majorcards', 'active'],axis=1,inplace=True)

#['card', 'reports', 'age', 'income', 'owner', 'selfemp', 'months']

# encoding categorical features to integers (integer encoding) 
df['card'] = df['card'].astype("category").cat.codes
df['owner']=df['owner'].astype("category").cat.codes
df['selfemp']=df['selfemp'].astype("category").cat.codes

# creating dictionary to get type of feature cat=categorical,num=numbercial
get_type = {'card':'cat', 'reports':'num', 'age':'num', 'income':'num', 'owner':'cat', 'selfemp':'cat', 'months':'num'}

#dictionary of list to store answer
ansers_knn= {'card':[], 'reports':[], 'age':[], 'income':[], 'owner':[], 'selfemp':[], 'months':[]}
ansers_wknn= {'card':[], 'reports':[], 'age':[], 'income':[], 'owner':[], 'selfemp':[], 'months':[]}
ansers_all= {'card':[], 'reports':[], 'age':[], 'income':[], 'owner':[], 'selfemp':[], 'months':[]}

df.head()
# Out:
#    card  reports       age  income  owner  selfemp  months
# 0     1        0  37.66667  4.5200      1        0      54
# 1     1        0  33.25000  2.4200      0        0      34
# 2     1        0  33.66667  4.5000      1        0      58
# 3     1        0  30.50000  2.5400      0        0      25
# 4     1        0  32.16667  9.7867      1        0      64

# %%
class KNN:
    
    def __init__(self,x_train,y_train,data_type,col_list,weights=False,dist='euc',K=1):
        # x_train = input features training dataset
        # y_train = output labels of training dataset
        # data_type - ['num','cat'] what is datatype of output label
        # weights = weights=True for weighted KNN
        # dist - ['euc','ham','chi'] which distance measure to use
        # K - value of K in KNN
        
        self.x_train = x_train
        self.y_train = y_train
        self.dist = dist
        self.K = K
        self.data_type =data_type
        self.weights = weights
        self.col_list =col_list
            
        if dist=='euc':
            self.dist = self.euclidian_dist
        elif dist=='chi':
            self.dist = self.chi_square_dist
        else:
            self.dist = self.hamming_dist
            
    def euclidian_dist(self,point1,point2):
        dist=0
        for m in range(len(point1)):
            dist+=  (point1[m]-point2[m])**2
        return math.sqrt(dist)

    def chi_square_dist(self,point1,point2):
        dist=0
        for m in range(len(point1)):
            if get_type[self.col_list[m]] == 'num':
                dist+= ((point1[m]-point2[m])**2) /(0.1+point1[m]+point2[m]) 
            else:
                dist+= 2*abs(point1[m]-point2[m]) 
        return dist/2.0
    
    def hamming_dist(self,point1,point2):
        dist=0
        for m in range(len(point1)):
            dist+=  abs(point1[m]-point2[m])
        
        return dist
    
    #defining weight
    def W(self,X):
        w= 1 if X==0.0 else 1/(X**2)
        return w
    
    #prectict label for given point p
    def predict(self,point):
        
        distances = []
        #iterate through all training data
        for p,i in zip(self.x_train,range(len(self.x_train))):
            # get distance according to selected distance measure
            d=self.dist(point,p)
            # append distance with label in list of tuples [(dist,label), ...] 
            distances.append((d,self.y_train[i]))
        
        #sort according to distance
        distances.sort()
        
        # if label to be predicted is numerical
        if self.data_type == 'num':
            dist_sum=0.0
            sum_w = 0.0
            # if we need to find weighted KNN 
            if self.weights ==True:
                for i in range(len(self.x_train)):
                    wi = self.W(distances[i][0])
                    dist_sum+=wi*distances[i][1]
                    sum_w += wi
                sum_w = round(sum_w,2)
                return round(dist_sum/sum_w,2) if sum_w > 0.01 else dist_sum 
            
            # if it is normal KNN 
            else:
                for i in range(self.K):
                    dist_sum+=distances[i][1]
                return round(dist_sum/self.K,2)
            
        # else if label to be predicted is categorical
        else:
           #if we need to find weighted KNN 
            if self.weights ==True:
                lbs = {}
                # add all weights for label
                for i in range(len(self.x_train)):
                    if distances[i][1] in lbs.keys():
                        lbs[distances[i][1]]+=self.W(distances[i][0])
                    else:
                        lbs[distances[i][1]]=self.W(distances[i][0])
                max_weight =0
                label_ans=0
                # find the label with max total weight
                for label in lbs.keys():
                    if max_weight < lbs[label]:
                        max_weight = lbs[label]
                        label_ans = label
                return label_ans
            
            # if it is normal KNN   
            else:
                lbs =[]
                # find the MODE(most occuring) of labels in nearest K neighbours
                for i in range(self.K):
                    lbs.append(distances[i][1])

                return stats.mode(lbs).mode[0]

# %%
# defining accuracy measure
def calculate_accuracy(y_true, y_pred, data_type):
    if data_type == 'num':
        return r2_score(y_true, y_pred)
    else:
        return accuracy_score(y_true, y_pred)

N = len(df) #total number of samples

removal_percent_list = [0.05,0.10,0.20]
col_name_list = ['card', 'reports', 'age', 'income', 'owner', 'selfemp', 'months']


# removal_percent = 0.05
# col_name = 'income'
for col_name in col_name_list:
    feature_list = col_name_list.copy()
    feature_list.remove(col_name)
    for removal_percent in removal_percent_list:
        
        # calculate  num = removal_percent * total_rows
        num = int(np.rint(removal_percent * N))

        # genrate num ramdom interger in range [0,N)
        row_nums = random.sample(range(num),num)
        
        # make copy of dataframe so that maipulation are made on copy
        df_copy = df.copy()
        
        # initialize standard scaler
        scaler = StandardScaler()
        
        # column list that contains all col name except curr col : used for scaling
        feature_cols  = [x for x in col_name_list if not col_name==x]
        
        # scale all columns except label column
        df_copy[feature_cols] = scaler.fit_transform(df_copy[feature_cols])
        df_copy[col_name] = df[col_name].copy()
        
        
        # replace actual values with NaN in the randomly genrated rows and store actual values in target_values list to
        # calculate accuracy later
        target_values = []
        for i in row_nums:
            target_values.append(df_copy[col_name][i])
            df_copy[col_name][i] = np.NaN
            
        # test data will contain rows without missing values
        test_data = df_copy[pd.isnull(df_copy[col_name])].copy()
        
        # test data will contain rows who have missing values
        train_data = df_copy[pd.isnull(df_copy[col_name])==False].copy()
        
        
        
        # split data into input feature and target values
        X_train = train_data.drop(col_name,axis=1).values
        Y_train = train_data[col_name].values
        
        # split data into input feature and target values
        X_test = test_data.drop(col_name,axis=1).values
        Y_test = np.ravel(np.array(target_values))
        
        for val_of_k in [1,7,'weighted']:
            
            for dist_mes in ['euc','ham','chi']:
                
                if val_of_k == 'weighted':
                    
                    val_K=5
                    weight = [1,2,3,4,5,6]
                    knn = KNN(X_train,Y_train,get_type[col_name],feature_list,dist=dist_mes,K=val_K,weights=weight)
                    Y_pred=[]
                    error =0
                    for i in range(len(X_test)):
                        y=knn.predict(X_test[i])
                        Y_pred.append(y)
                        error+=abs(y-Y_test[i])
                    error = calculate_accuracy(Y_test,np.array(Y_pred),get_type[col_name])
                    print("Column Name : ",col_name,"Removal % :",removal_percent*100,"Weighted KNN :",weight,"Distance Measure : ",dist_mes,"Error : ",error)
                    ansers_wknn[col_name].append(error)
                    ansers_all[col_name].append(error)
                else:
                    
                    knn = KNN(X_train,Y_train,get_type[col_name],feature_list,dist=dist_mes,K=val_of_k)
                    Y_pred=[]
                    error =0
                    for i in range(len(X_test)):
                        y=knn.predict(X_test[i])
                        Y_pred.append(y)
                        error+=abs(y-Y_test[i])
                    error = calculate_accuracy(Y_test,np.array(Y_pred),get_type[col_name])
                    print("Column Name : ",col_name,"Removal % :",removal_percent*100,"K : ",val_of_k,"Distance Measure : ",dist_mes,"Error : ",error)
                    ansers_knn[col_name].append(error)
                    ansers_all[col_name].append(error)
# Out:
# Column Name :  card Removal % : 5.0 K :  1 Distance Measure :  euc Error :  0.696969696969697
# Column Name :  card Removal % : 5.0 K :  1 Distance Measure :  ham Error :  0.696969696969697
# Column Name :  card Removal % : 5.0 K :  1 Distance Measure :  chi Error :  0.7424242424242424
# Column Name :  card Removal % : 5.0 K :  7 Distance Measure :  euc Error :  0.7272727272727273
# Column Name :  card Removal % : 5.0 K :  7 Distance Measure :  ham Error :  0.7424242424242424
# Column Name :  card Removal % : 5.0 K :  7 Distance Measure :  chi Error :  0.7424242424242424
# Column Name :  card Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.7121212121212122
# Column Name :  card Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.7121212121212122
# Column Name :  card Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.7575757575757576
# Column Name :  card Removal % : 10.0 K :  1 Distance Measure :  euc Error :  0.6515151515151515
# Column Name :  card Removal % : 10.0 K :  1 Distance Measure :  ham Error :  0.6666666666666666
# Column Name :  card Removal % : 10.0 K :  1 Distance Measure :  chi Error :  0.6742424242424242
# Column Name :  card Removal % : 10.0 K :  7 Distance Measure :  euc Error :  0.6742424242424242
# Column Name :  card Removal % : 10.0 K :  7 Distance Measure :  ham Error :  0.6742424242424242
# Column Name :  card Removal % : 10.0 K :  7 Distance Measure :  chi Error :  0.7272727272727273
# Column Name :  card Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.6818181818181818
# Column Name :  card Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.6742424242424242
# Column Name :  card Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.7272727272727273
# Column Name :  card Removal % : 20.0 K :  1 Distance Measure :  euc Error :  0.6666666666666666
# Column Name :  card Removal % : 20.0 K :  1 Distance Measure :  ham Error :  0.6477272727272727
# Column Name :  card Removal % : 20.0 K :  1 Distance Measure :  chi Error :  0.625
# Column Name :  card Removal % : 20.0 K :  7 Distance Measure :  euc Error :  0.6893939393939394
# Column Name :  card Removal % : 20.0 K :  7 Distance Measure :  ham Error :  0.678030303030303
# Column Name :  card Removal % : 20.0 K :  7 Distance Measure :  chi Error :  0.7386363636363636
# Column Name :  card Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.696969696969697
# Column Name :  card Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.7007575757575758
# Column Name :  card Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.7424242424242424
# Column Name :  reports Removal % : 5.0 K :  1 Distance Measure :  euc Error :  -1.8453206239168112
# Column Name :  reports Removal % : 5.0 K :  1 Distance Measure :  ham Error :  -2.231369150779896
# Column Name :  reports Removal % : 5.0 K :  1 Distance Measure :  chi Error :  -0.28682842287694976
# Column Name :  reports Removal % : 5.0 K :  7 Distance Measure :  euc Error :  -0.8781746967071056
# Column Name :  reports Removal % : 5.0 K :  7 Distance Measure :  ham Error :  -0.9497924176776427
# Column Name :  reports Removal % : 5.0 K :  7 Distance Measure :  chi Error :  -0.3887023396880416
# Column Name :  reports Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -1.064644714038128
# Column Name :  reports Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -1.1332755632582323
# Column Name :  reports Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.3440207972270364
# Column Name :  reports Removal % : 10.0 K :  1 Distance Measure :  euc Error :  -1.711585866885784
# Column Name :  reports Removal % : 10.0 K :  1 Distance Measure :  ham Error :  -2.199671322925225
# Column Name :  reports Removal % : 10.0 K :  1 Distance Measure :  chi Error :  -1.3251848808545597
# Column Name :  reports Removal % : 10.0 K :  7 Distance Measure :  euc Error :  -0.8382226992604762
# Column Name :  reports Removal % : 10.0 K :  7 Distance Measure :  ham Error :  -0.8519351889893176
# Column Name :  reports Removal % : 10.0 K :  7 Distance Measure :  chi Error :  -0.2971623459326207
# Column Name :  reports Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.9024486442070658
# Column Name :  reports Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.976474938373048
# Column Name :  reports Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.40351684470008164
# Column Name :  reports Removal % : 20.0 K :  1 Distance Measure :  euc Error :  -1.0780064240584517
# Column Name :  reports Removal % : 20.0 K :  1 Distance Measure :  ham Error :  -1.3319332180297203
# Column Name :  reports Removal % : 20.0 K :  1 Distance Measure :  chi Error :  -0.8031131975574459
# Column Name :  reports Removal % : 20.0 K :  7 Distance Measure :  euc Error :  -0.4463330062475732
# Column Name :  reports Removal % : 20.0 K :  7 Distance Measure :  ham Error :  -0.42580011295047826
# Column Name :  reports Removal % : 20.0 K :  7 Distance Measure :  chi Error :  -0.09042921181744368
# Column Name :  reports Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.43932229713035165
# Column Name :  reports Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.46727754050333536
# Column Name :  reports Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.111314108220677
# Column Name :  age Removal % : 5.0 K :  1 Distance Measure :  euc Error :  -2.7890639864486357
# Column Name :  age Removal % : 5.0 K :  1 Distance Measure :  ham Error :  -2.387223297018468
# Column Name :  age Removal % : 5.0 K :  1 Distance Measure :  chi Error :  -2.0823517012996673
# Column Name :  age Removal % : 5.0 K :  7 Distance Measure :  euc Error :  -0.5868195408748806
# Column Name :  age Removal % : 5.0 K :  7 Distance Measure :  ham Error :  -0.5283475954334369
# Column Name :  age Removal % : 5.0 K :  7 Distance Measure :  chi Error :  -0.62632100101085
# Column Name :  age Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.7210007337122497
# Column Name :  age Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.6778863043250429
# Column Name :  age Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.7282065501908692
# Column Name :  age Removal % : 10.0 K :  1 Distance Measure :  euc Error :  -1.3015994984695678
# Column Name :  age Removal % : 10.0 K :  1 Distance Measure :  ham Error :  -1.24587228051936
# Column Name :  age Removal % : 10.0 K :  1 Distance Measure :  chi Error :  -1.388389580363897
# Column Name :  age Removal % : 10.0 K :  7 Distance Measure :  euc Error :  -0.4653979991242707
# Column Name :  age Removal % : 10.0 K :  7 Distance Measure :  ham Error :  -0.5055923925113845
# Column Name :  age Removal % : 10.0 K :  7 Distance Measure :  chi Error :  -0.5355034085456214
# Column Name :  age Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.45816242821870934
# Column Name :  age Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.6350889759664842
# Column Name :  age Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.6335031248002447
# Column Name :  age Removal % : 20.0 K :  1 Distance Measure :  euc Error :  -0.5650949698081302
# Column Name :  age Removal % : 20.0 K :  1 Distance Measure :  ham Error :  -0.6636667735672435
# Column Name :  age Removal % : 20.0 K :  1 Distance Measure :  chi Error :  -0.9781134913362779
# Column Name :  age Removal % : 20.0 K :  7 Distance Measure :  euc Error :  -0.2023594427669031
# Column Name :  age Removal % : 20.0 K :  7 Distance Measure :  ham Error :  -0.16512146181767484
# Column Name :  age Removal % : 20.0 K :  7 Distance Measure :  chi Error :  -0.23433562853367884
# Column Name :  age Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.2094904729663687
# Column Name :  age Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.213077438007246
# Column Name :  age Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.3070908385583382
# Column Name :  income Removal % : 5.0 K :  1 Distance Measure :  euc Error :  -0.9116825323099336
# Column Name :  income Removal % : 5.0 K :  1 Distance Measure :  ham Error :  -0.9394829015256305
# Column Name :  income Removal % : 5.0 K :  1 Distance Measure :  chi Error :  -0.8331508266288843
# Column Name :  income Removal % : 5.0 K :  7 Distance Measure :  euc Error :  -0.31586748170243806
# Column Name :  income Removal % : 5.0 K :  7 Distance Measure :  ham Error :  -0.2632012611116954
# Column Name :  income Removal % : 5.0 K :  7 Distance Measure :  chi Error :  -0.09032267776401293
# Column Name :  income Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.4034422132950448
# Column Name :  income Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.3439974782940882
# Column Name :  income Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.28403920295787954
# Column Name :  income Removal % : 10.0 K :  1 Distance Measure :  euc Error :  -0.6089549617359555
# Column Name :  income Removal % : 10.0 K :  1 Distance Measure :  ham Error :  -0.6243142033286717
# Column Name :  income Removal % : 10.0 K :  1 Distance Measure :  chi Error :  -0.5019730630554049
# Column Name :  income Removal % : 10.0 K :  7 Distance Measure :  euc Error :  -0.1758959221812857
# Column Name :  income Removal % : 10.0 K :  7 Distance Measure :  ham Error :  -0.1866541610113892
# Column Name :  income Removal % : 10.0 K :  7 Distance Measure :  chi Error :  -0.25873413641400145
# Column Name :  income Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.22325177103310412
# Column Name :  income Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.19282645310132773
# Column Name :  income Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.2889400058170488
# Column Name :  income Removal % : 20.0 K :  1 Distance Measure :  euc Error :  -0.9498100503873073
# Column Name :  income Removal % : 20.0 K :  1 Distance Measure :  ham Error :  -0.8933675208252869
# Column Name :  income Removal % : 20.0 K :  1 Distance Measure :  chi Error :  -0.47377055961900916
# Column Name :  income Removal % : 20.0 K :  7 Distance Measure :  euc Error :  -0.23653238649946462
# Column Name :  income Removal % : 20.0 K :  7 Distance Measure :  ham Error :  -0.23355911529194007
# Column Name :  income Removal % : 20.0 K :  7 Distance Measure :  chi Error :  -0.1619676372584975
# Column Name :  income Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.27812901868556494
# Column Name :  income Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.267790828850309
# Column Name :  income Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.22212619894047214
# Column Name :  owner Removal % : 5.0 K :  1 Distance Measure :  euc Error :  0.4090909090909091
# Column Name :  owner Removal % : 5.0 K :  1 Distance Measure :  ham Error :  0.4090909090909091
# Column Name :  owner Removal % : 5.0 K :  1 Distance Measure :  chi Error :  0.6363636363636364
# Column Name :  owner Removal % : 5.0 K :  7 Distance Measure :  euc Error :  0.4393939393939394
# Column Name :  owner Removal % : 5.0 K :  7 Distance Measure :  ham Error :  0.4393939393939394
# Column Name :  owner Removal % : 5.0 K :  7 Distance Measure :  chi Error :  0.5757575757575758
# Column Name :  owner Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.5
# Column Name :  owner Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.5151515151515151
# Column Name :  owner Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.5909090909090909
# Column Name :  owner Removal % : 10.0 K :  1 Distance Measure :  euc Error :  0.5075757575757576
# Column Name :  owner Removal % : 10.0 K :  1 Distance Measure :  ham Error :  0.553030303030303
# Column Name :  owner Removal % : 10.0 K :  1 Distance Measure :  chi Error :  0.48484848484848486
# Column Name :  owner Removal % : 10.0 K :  7 Distance Measure :  euc Error :  0.5378787878787878
# Column Name :  owner Removal % : 10.0 K :  7 Distance Measure :  ham Error :  0.5303030303030303
# Column Name :  owner Removal % : 10.0 K :  7 Distance Measure :  chi Error :  0.4696969696969697
# Column Name :  owner Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.553030303030303
# Column Name :  owner Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.553030303030303
# Column Name :  owner Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.4696969696969697
# Column Name :  owner Removal % : 20.0 K :  1 Distance Measure :  euc Error :  0.5113636363636364
# Column Name :  owner Removal % : 20.0 K :  1 Distance Measure :  ham Error :  0.5151515151515151
# Column Name :  owner Removal % : 20.0 K :  1 Distance Measure :  chi Error :  0.5227272727272727
# Column Name :  owner Removal % : 20.0 K :  7 Distance Measure :  euc Error :  0.5
# Column Name :  owner Removal % : 20.0 K :  7 Distance Measure :  ham Error :  0.4734848484848485
# Column Name :  owner Removal % : 20.0 K :  7 Distance Measure :  chi Error :  0.48863636363636365
# Column Name :  owner Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.49242424242424243
# Column Name :  owner Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.49242424242424243
# Column Name :  owner Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.4962121212121212
# Column Name :  selfemp Removal % : 5.0 K :  1 Distance Measure :  euc Error :  0.9090909090909091
# Column Name :  selfemp Removal % : 5.0 K :  1 Distance Measure :  ham Error :  0.9090909090909091
# Column Name :  selfemp Removal % : 5.0 K :  1 Distance Measure :  chi Error :  0.8787878787878788
# Column Name :  selfemp Removal % : 5.0 K :  7 Distance Measure :  euc Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 5.0 K :  7 Distance Measure :  ham Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 5.0 K :  7 Distance Measure :  chi Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 10.0 K :  1 Distance Measure :  euc Error :  0.8939393939393939
# Column Name :  selfemp Removal % : 10.0 K :  1 Distance Measure :  ham Error :  0.9015151515151515
# Column Name :  selfemp Removal % : 10.0 K :  1 Distance Measure :  chi Error :  0.8863636363636364
# Column Name :  selfemp Removal % : 10.0 K :  7 Distance Measure :  euc Error :  0.946969696969697
# Column Name :  selfemp Removal % : 10.0 K :  7 Distance Measure :  ham Error :  0.946969696969697
# Column Name :  selfemp Removal % : 10.0 K :  7 Distance Measure :  chi Error :  0.946969696969697
# Column Name :  selfemp Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.946969696969697
# Column Name :  selfemp Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.946969696969697
# Column Name :  selfemp Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.946969696969697
# Column Name :  selfemp Removal % : 20.0 K :  1 Distance Measure :  euc Error :  0.9015151515151515
# Column Name :  selfemp Removal % : 20.0 K :  1 Distance Measure :  ham Error :  0.8977272727272727
# Column Name :  selfemp Removal % : 20.0 K :  1 Distance Measure :  chi Error :  0.8636363636363636
# Column Name :  selfemp Removal % : 20.0 K :  7 Distance Measure :  euc Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 20.0 K :  7 Distance Measure :  ham Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 20.0 K :  7 Distance Measure :  chi Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  0.9356060606060606
# Column Name :  selfemp Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  0.9393939393939394
# Column Name :  selfemp Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  0.9356060606060606
# Column Name :  months Removal % : 5.0 K :  1 Distance Measure :  euc Error :  -1.5791018173635387
# Column Name :  months Removal % : 5.0 K :  1 Distance Measure :  ham Error :  -1.4326792677508338
# Column Name :  months Removal % : 5.0 K :  1 Distance Measure :  chi Error :  -2.1331530992840575
# Column Name :  months Removal % : 5.0 K :  7 Distance Measure :  euc Error :  -0.33346778303832303
# Column Name :  months Removal % : 5.0 K :  7 Distance Measure :  ham Error :  -0.31676850372378196
# Column Name :  months Removal % : 5.0 K :  7 Distance Measure :  chi Error :  -0.4197622345112295
# Column Name :  months Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.40382512154961336
# Column Name :  months Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.4587691293624472
# Column Name :  months Removal % : 5.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.5610870293319123
# Column Name :  months Removal % : 10.0 K :  1 Distance Measure :  euc Error :  -0.9517099749078004
# Column Name :  months Removal % : 10.0 K :  1 Distance Measure :  ham Error :  -1.0667367464214363
# Column Name :  months Removal % : 10.0 K :  1 Distance Measure :  chi Error :  -1.961309962340032
# Column Name :  months Removal % : 10.0 K :  7 Distance Measure :  euc Error :  -0.41978308034379386
# Column Name :  months Removal % : 10.0 K :  7 Distance Measure :  ham Error :  -0.3523883043913518
# Column Name :  months Removal % : 10.0 K :  7 Distance Measure :  chi Error :  -0.21241328085387146
# Column Name :  months Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.39902229262098676
# Column Name :  months Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.5039112628873799
# Column Name :  months Removal % : 10.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.3473055029490921
# Column Name :  months Removal % : 20.0 K :  1 Distance Measure :  euc Error :  -1.7225051794388269
# Column Name :  months Removal % : 20.0 K :  1 Distance Measure :  ham Error :  -1.9166064595499037
# Column Name :  months Removal % : 20.0 K :  1 Distance Measure :  chi Error :  -1.75903284948666
# Column Name :  months Removal % : 20.0 K :  7 Distance Measure :  euc Error :  -0.5517910647865389
# Column Name :  months Removal % : 20.0 K :  7 Distance Measure :  ham Error :  -0.5638699660873019
# Column Name :  months Removal % : 20.0 K :  7 Distance Measure :  chi Error :  -0.2903369635693591
# Column Name :  months Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  euc Error :  -0.6125047267215504
# Column Name :  months Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  ham Error :  -0.6342338871018149
# Column Name :  months Removal % : 20.0 Weighted KNN : [1, 2, 3, 4, 5, 6] Distance Measure :  chi Error :  -0.31422731146364247

# %%
# l1 = ['Euclidian','Hamming','Manhattab']*6
# l2 = [['K=1']*3,['K=5']*3]*3
# l3 = [['5% Missing']*6,['10% Missing']*6,['20% Missing']*6]
# l2=list(np.ravel(np.array(l2)))
# l3=list(np.ravel(np.array(l3)))
# pd.DataFrame(ansers_knn,index=[l3,l2,l1])

# %%
# l1 = ['Euclidian','Hamming','Manhattan']*3
# l2 = ['K=5']*9
# l3 = [['5% Missing']*3,['10% Missing']*3,['20% Missing']*3]
# l3=list(np.ravel(np.array(l3)))
# pd.DataFrame(ansers_wknn,index=[l3,l2,l1])

# %%
l1 = ['Euclidian','Hamming','Chi Square']*9
l2 = [['K=1']*3,['K=7']*3,['Weighted']*3]*3
l3 = [['5% Missing']*9,['10% Missing']*9,['20% Missing']*9]
l2=list(np.ravel(np.array(l2)))
l3=list(np.ravel(np.array(l3)))
tb = pd.DataFrame(ansers_all,index=[l3,l2,l1])
tb.to_csv('scaled_zscore_imputation.csv')

# %%
print("Accuracy For each column with different methods (scaled data - z score)")
tb
# Out:
# Accuracy For each column with different methods (scaled data - z score)
#                                      card   reports       age    income  \
# 5% Missing  K=1      Euclidian   0.696970 -1.845321 -2.789064 -0.911683
#                      Hamming     0.696970 -2.231369 -2.387223 -0.939483
#                      Chi Square  0.742424 -0.286828 -2.082352 -0.833151
#             K=7      Euclidian   0.727273 -0.878175 -0.586820 -0.315867
#                      Hamming     0.742424 -0.949792 -0.528348 -0.263201
#                      Chi Square  0.742424 -0.388702 -0.626321 -0.090323
#             Weighted Euclidian   0.712121 -1.064645 -0.721001 -0.403442
#                      Hamming     0.712121 -1.133276 -0.677886 -0.343997
#                      Chi Square  0.757576 -0.344021 -0.728207 -0.284039
# 10% Missing K=1      Euclidian   0.651515 -1.711586 -1.301599 -0.608955
#                      Hamming     0.666667 -2.199671 -1.245872 -0.624314
#                      Chi Square  0.674242 -1.325185 -1.388390 -0.501973
#             K=7      Euclidian   0.674242 -0.838223 -0.465398 -0.175896
#                      Hamming     0.674242 -0.851935 -0.505592 -0.186654
#                      Chi Square  0.727273 -0.297162 -0.535503 -0.258734
#             Weighted Euclidian   0.681818 -0.902449 -0.458162 -0.223252
#                      Hamming     0.674242 -0.976475 -0.635089 -0.192826
#                      Chi Square  0.727273 -0.403517 -0.633503 -0.288940
# 20% Missing K=1      Euclidian   0.666667 -1.078006 -0.565095 -0.949810
#                      Hamming     0.647727 -1.331933 -0.663667 -0.893368
#                      Chi Square  0.625000 -0.803113 -0.978113 -0.473771
#             K=7      Euclidian   0.689394 -0.446333 -0.202359 -0.236532
#                      Hamming     0.678030 -0.425800 -0.165121 -0.233559
#                      Chi Square  0.738636 -0.090429 -0.234336 -0.161968
#             Weighted Euclidian   0.696970 -0.439322 -0.209490 -0.278129
#                      Hamming     0.700758 -0.467278 -0.213077 -0.267791
#                      Chi Square  0.742424 -0.111314 -0.307091 -0.222126
#
#                                     owner   selfemp    months
# 5% Missing  K=1      Euclidian   0.409091  0.909091 -1.579102
#                      Hamming     0.409091  0.909091 -1.432679
#                      Chi Square  0.636364  0.878788 -2.133153
#             K=7      Euclidian   0.439394  0.939394 -0.333468
#                      Hamming     0.439394  0.939394 -0.316769
#                      Chi Square  0.575758  0.939394 -0.419762
#             Weighted Euclidian   0.500000  0.939394 -0.403825
#                      Hamming     0.515152  0.939394 -0.458769
#                      Chi Square  0.590909  0.939394 -0.561087
# 10% Missing K=1      Euclidian   0.507576  0.893939 -0.951710
#                      Hamming     0.553030  0.901515 -1.066737
#                      Chi Square  0.484848  0.886364 -1.961310
#             K=7      Euclidian   0.537879  0.946970 -0.419783
#                      Hamming     0.530303  0.946970 -0.352388
#                      Chi Square  0.469697  0.946970 -0.212413
#             Weighted Euclidian   0.553030  0.946970 -0.399022
#                      Hamming     0.553030  0.946970 -0.503911
#                      Chi Square  0.469697  0.946970 -0.347306
# 20% Missing K=1      Euclidian   0.511364  0.901515 -1.722505
#                      Hamming     0.515152  0.897727 -1.916606
#                      Chi Square  0.522727  0.863636 -1.759033
#             K=7      Euclidian   0.500000  0.939394 -0.551791
#                      Hamming     0.473485  0.939394 -0.563870
#                      Chi Square  0.488636  0.939394 -0.290337
#             Weighted Euclidian   0.492424  0.935606 -0.612505
#                      Hamming     0.492424  0.939394 -0.634234
#                      Chi Square  0.496212  0.935606 -0.314227

# %%
#for plotting bar graph

def plot_bar_x(no_movies,label,col_n):
    # this is for plotting purpose
    index = np.arange(len(label))
    plt.bar(index, no_movies)
    plt.xlabel('Accuracy', fontsize=5)
    plt.ylabel('method', fontsize=5)
    plt.xticks(index, label, fontsize=5, rotation=30)
    plt.title('Accuracy for '+ col_n)
    plt.show()
    
y_Ax =["5% Missing,K=1,Euclidian,"
,"5% Missing,K=1,Hamming,"
,"5% Missing,K=1,Chi Square,"
,"5% Missing,K=7,Euclidian,"
,"5% Missing,K=7,Hamming,"
,"5% Missing,K=7,Chi Square,"
,"5% Missing,Weighted,Euclidian,"
,"5% Missing,Weighted,Hamming,"
,"5% Missing,Weighted,Chi Square,"
,"10% Missing,K=1,Euclidian,"
,"10% Missing,K=1,Hamming,"
,"10% Missing,K=1,Chi Square,"
,"10% Missing,K=7,Euclidian,"
,"10% Missing,K=7,Hamming,"
,"10% Missing,K=7,Chi Square,"
,"10% Missing,Weighted,Euclidian,"
,"10% Missing,Weighted,Hamming,"
,"10% Missing,Weighted,Chi Square,"
,"20% Missing,K=1,Euclidian,"
,"20% Missing,K=1,Hamming,"
,"20% Missing,K=1,Chi Square,"
,"20% Missing,K=7,Euclidian,"
,"20% Missing,K=7,Hamming,"
,"20% Missing,K=7,Chi Square,"
,"20% Missing,Weighted,Euclidian,"
,"20% Missing,Weighted,Hamming,"
,"20% Missing,Weighted,Chi Square,"]

# %%
#plotting accurracy for each column with different combinations
for col_n in col_name_list:    
    plot_bar_x(ansers_all[col_n],y_Ax,col_n)
